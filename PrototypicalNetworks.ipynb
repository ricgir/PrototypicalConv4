# %%
# !git clone https://github.com/yinboc/prototypical-network-pytorch.git
# Out:
# Cloning into 'prototypical-network-pytorch'...
# remote: Enumerating objects: 55, done.
# remote: Total 55 (delta 0), reused 0 (delta 0), pack-reused 55 (from 1)
# Receiving objects: 100% (55/55), 174.72 KiB | 941.00 KiB/s, done.
# Resolving deltas: 100% (26/26), done.

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-73653fc1-873a-452b-b67c-c95f72a0bb5c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-73653fc1-873a-452b-b67c-c95f72a0bb5c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Install gdown
# !pip install gdown

# Create the directory structure specified in the readme
# !mkdir -p materials/images

# Download the file using the ID from the URL
# The URL is: https://drive.google.com/open?id=0B3Irx3uQNoBMQ1FlNXJsZUdYWEE
# The ID is: 0B3Irx3uQNoBMQ1FlNXJsZUdYWEE
# !gdown '0B3Irx3uQNoBMQ1FlNXJsZUdYWEE'

# --- IMPORTANT ---
# The previous command will download a file (likely a .zip or .tar archive).
# You need to find its name and extract it into the 'materials/images' folder.

# 1. List files to find the downloaded file's name:
# !ls

# 2. Assuming the file is 'images.zip' (REPLACE with actual name):
# If it's a zip file:
# !unzip YOUR_FILE_NAME.zip -d materials/images
# If it's a tar.gz file:
# !tar -xzf YOUR_FILE_NAME.tar.gz -C materials/images
# Out:
# ...
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=0B3Irx3uQNoBMQ1FlNXJsZUdYWEE
#
# but Gdown can't. Please check connections and permissions.
# convnet.py  mini_imagenet.py  samplers.py  train.py
# materials   sample_data       test.py	   utils.py

# %%
# !python train.py --gpu 0
# Out:
# {'gpu': '0',
#  'max_epoch': 200,
#  'query': 15,
#  'save_epoch': 20,
#  'save_path': './save/proto-1',
#  'shot': 1,
#  'test_way': 5,
#  'train_way': 30}
# using gpu: 0
# Traceback (most recent call last):
#   File "/content/train.py", line 30, in <module>
#     trainset = MiniImageNet('train')
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/mini_imagenet.py", line 15, in __init__
#     lines = [x.strip() for x in open(csv_path, 'r').readlines()][1:]
#                                 ^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './materials/train.csv'

# %%
# !gdown '0B3Irx3uQNoBMQ1FlNXJsZUdYWEE' -O ./materials/mini-imagenet.tar.gz
# Out:
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=0B3Irx3uQNoBMQ1FlNXJsZUdYWEE
#
# but Gdown can't. Please check connections and permissions.

# %%
# Make sure you have created cifar100.py
# Make sure you have modified train.py and test.py

# Now, just run the training command:
# !python train.py --dataset cifar100 --gpu 0 --save-path ./save/cifar-proto-1

# This creates a folder "MyColabModels" in your Drive
# !python train.py --dataset cifar100 --gpu 0 --save-path "/content/drive/My Drive/MyColabModels/cifar-proto-1"
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 151, train 51/100, loss=2.6010 acc=0.2356
# epoch 151, train 52/100, loss=2.7590 acc=0.1800
# epoch 151, train 53/100, loss=2.9473 acc=0.1933
# epoch 151, train 54/100, loss=2.8573 acc=0.2022
# epoch 151, train 55/100, loss=2.6269 acc=0.2222
# epoch 151, train 56/100, loss=2.9465 acc=0.1533
# epoch 151, train 57/100, loss=2.8016 acc=0.1689
# epoch 151, train 58/100, loss=2.4667 acc=0.2800
# epoch 151, train 59/100, loss=2.6883 acc=0.2333
# epoch 151, train 60/100, loss=2.6892 acc=0.2311
# epoch 151, train 61/100, loss=2.8461 acc=0.1667
# epoch 151, train 62/100, loss=2.7787 acc=0.2400
# epoch 151, train 63/100, loss=2.8273 acc=0.2089
# epoch 151, train 64/100, loss=2.5877 acc=0.2067
# epoch 151, train 65/100, loss=2.6490 acc=0.2089
# epoch 151, train 66/100, loss=2.6292 acc=0.2533
# epoch 151, train 67/100, loss=2.6602 acc=0.2333
# epoch 151, train 68/100, loss=2.6998 acc=0.2156
# ...

# %%
#!python test.py --dataset cifar100 --load ./save/cifar-proto-1/max-acc.pth --gpu 0
# !python test.py --dataset cifar100 --load "/content/drive/My Drive/MyColabModels/cifar-proto-1/max-acc.pth" --gpu 0
# Out:
# {'batch': 2000,
#  'dataset': 'cifar100',
#  'gpu': '0',
#  'load': '/content/drive/My Drive/MyColabModels/cifar-proto-1/max-acc.pth',
#  'query': 30,
#  'shot': 1,
#  'way': 5}
# using gpu: 0
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# batch 1: 61.33(61.33)
# batch 2: 54.33(47.33)
# batch 3: 50.89(44.00)
# batch 4: 48.50(41.33)
# batch 5: 48.00(46.00)
# batch 6: 50.67(64.00)
# batch 7: 53.05(67.33)
# batch 8: 55.08(69.33)
# batch 9: 54.74(52.00)
# batch 10: 54.00(47.33)
# batch 11: 52.12(33.33)
# batch 12: 52.17(52.67)
# batch 13: 52.26(53.33)
# batch 14: 53.71(72.67)
# ...
